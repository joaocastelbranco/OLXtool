# %% [markdown]
# # Automação Web e Busca de Informações com Python

# %%
#variáveis
#minutos de intervalo de rodagem de código
tempo_rodagem_codigo = '15'
#número de paginas a fazer pesquisa
page_list = [1,2]

#nomes dos concorrentes
nomes_concorrentes = ['concorrente1','concorrente2']

#Filtros de modelos e precos. p é preco minimo; P é preco máximo (por modelo)
modelos_a_manter =  ['14', '13']
p13 = 500
P13 = 870
p14 = 940
P14 = 1200


#Login OLX
username = 'joaocastelbranco44@gmail.com'
password = 'Comando44'
mensagem1 = 'Olá, estou interessado no Iphone.' 
mensagem2 = ' Poderia-me dizer se ainda está disponível? Obrigado.'

# %%
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in c:\users\joaoc\anaconda3\lib\site-packages (3.8.3)
# Requirement already satisfied: python-dotenv in c:\users\joaoc\anaconda3\lib\site-packages (from webdriver-manager) (0.20.0)
# Requirement already satisfied: tqdm in c:\users\joaoc\anaconda3\lib\site-packages (from webdriver-manager) (4.59.0)
# Requirement already satisfied: requests in c:\users\joaoc\anaconda3\lib\site-packages (from webdriver-manager) (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\joaoc\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joaoc\anaconda3\lib\site-packages (from requests->webdriver-manager) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\joaoc\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\joaoc\anaconda3\lib\site-packages (from requests->webdriver-manager) (4.0.0)

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time
from datetime import datetime
from random import randint
from lxml import html
import re
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
navegador = webdriver.Chrome(ChromeDriverManager().install())
from openpyxl import Workbook

# %%
#varáveis Xpath
a = '//*[@id="root"]/div[1]/div[2]/form/div[5]/div/div[2]/div['
b = ']/a/div/div/div[2]/div[1]/'
f = ']/a/div/div/div[2]/div[2]/p'
c = 'h6'
d = 'p'
e = ']/a'

#criar listas
descricao_lista = []
modelo_lista = []
preco_lista = []
link_lista = []
local_lista = []
data_lista = []

#abrir janela 
navegador = webdriver.Chrome(ChromeDriverManager().install())
navegador.maximize_window()

#loop para cada pagina    
for p in page_list: 
    navegador.get('https://www.olx.pt/d/telemoveis-e-tablets/telemoveis/benfica-lisboa/q-iphone/?search%5Bdist%5D=50&search%5Bfilter_float_price%3Afrom%5D=150&search%5Bfilter_enum_marca%5D%5B0%5D=iphone&page='+str(p))
    time.sleep(2)
    
    try :
        navegador.find_element_by_xpath('//*[@id="onetrust-accept-btn-handler"]').click()
    except NoSuchElementException:
            pass
    
    for i in range (2,60) :
        try:
            xpath_dinamico = a + str(i) + b
            preco=navegador.find_element_by_xpath(xpath_dinamico+d).text
            descricao=navegador.find_element_by_xpath(xpath_dinamico+c).text
            link_url=navegador.find_element_by_xpath(a + str(i)+e)
            link=link_url.get_attribute('href')
            local_data=navegador.find_element_by_xpath(a + str(i) + f).text    
        
        #modelo de iphone atraves da descricao
            try:
                text=descricao.upper()
                start = text.index('IPHONE')
                end = text.index(' ',start+8)
                modelo = text[start+1:end]
                modelo = modelo[6:8]
            except ValueError :
                pass
            try: 
                local_data_split = local_data.split("-")
            except ValueError :
                pass
            
            local = local_data_split[0]
            data = local_data_split[1]
            data = data[1:]
            hoje = datetime.today().strftime('%d-%m-%Y')
            data = data.replace('Hoje',hoje)
            data = data.replace('Para o topo','')
            preco = preco.replace('€','')
            preco = preco.replace(' \nNegociável','')
            preco = preco.replace('.','')                               
            preco = preco.replace(' ','')
            preco = preco.replace(',','.')
            preco = float(preco)
                    
            descricao_lista.append(descricao)
            modelo_lista.append(modelo)
            preco_lista.append(preco)
            link_lista.append(link)
            local_lista.append(local)
            data_lista.append(data)
            
            
        except NoSuchElementException:
            pass

navegador.quit()
print('Pesquisa feita')
# Out:
# ########################################################
# iPhone 11 Pro Max 256GB Cinzento A - Garantia 3 Anos
# 11
# 639.0
# https://www.olx.pt/d/anuncio/iphone-11-pro-max-256gb-cinzento-a-garantia-3-anos-IDH6P4g.html
# Santa Clara
#  a 28 de novembro de 2022
# ########################################################
# iPhone 13 Pro Max 128gb Sierra Blue - NOVO/SELADO C/Garantia Apple
# 13
# 1199.0
# https://www.olx.pt/d/anuncio/iphone-13-pro-max-128gb-sierra-blue-novo-selado-c-garantia-apple-IDHdGCI.html
# Montijo E Afonsoeiro
#  a 27 de novembro de 2022
# ########################################################
# iPhone 11 128GB Preto A - Garantia 3 Anos
# 11
# 439.0
# https://www.olx.pt/d/anuncio/iphone-11-128gb-preto-a-garantia-3-anos-IDF5TPn.html
# Santa Clara
#  a 28 de novembro de 2022
# ########################################################
# IPhone 11 128GB Silver
# 11
# 450.0
# https://www.olx.pt/d/anuncio/iphone-11-128gb-silver-IDHpPXo.html
# Odivelas
# 29 de novembro de 2022
# ########################################################
# iPhone 12 128GB Azul + Capa MagSafe iPhone 12 APPLE Transparente
# 12
# 620.0
# https://www.olx.pt/d/anuncio/iphone-12-128gb-azul-capa-magsafe-iphone-12-apple-transparente-IDHsBoO.html
# Avenidas Novas
# 29 de novembro de 2022
# ########################################################
# IPhone 11 128GB Black
# 11
# 400.0
# https://www.olx.pt/d/anuncio/iphone-11-128gb-black-IDGOLXW.html
# Alvalade
# 29 de novembro de 2022
# ########################################################
# IPhone 7 128GB Silver
# 7
# 150.0
# https://www.olx.pt/d/anuncio/iphone-7-128gb-silver-IDHpPVG.html
# Odivelas
# 29 de novembro de 2022
# ########################################################
# iPhone 12 Pro Max 128GB
# 12
# 1100.0
# https://www.olx.pt/d/anuncio/iphone-12-pro-max-128gb-IDHsEcT.html
# Colares
# 29 de novembro de 2022
# ########################################################
# Iphone X 64GB preto
# X
# 300.0
# https://www.olx.pt/d/anuncio/iphone-x-64gb-preto-IDHsCHp.html
# Moscavide E Portela
# 29 de novembro de 2022
# ########################################################
# Iphone X de 64 GB
# X
# 210.0
# https://www.olx.pt/d/anuncio/iphone-x-de-64-gb-IDHsDSe.html
# Algueirão
# em Martins
# ########################################################
# Iphone 12 Pro Max
# 12
# 760.0
# https://www.olx.pt/d/anuncio/iphone-12-pro-max-IDHszAz.html
# Arroios
# 29 de novembro de 2022
# ########################################################
# iPhone XS MAX usado
# XS
# 280.0
# https://www.olx.pt/d/anuncio/iphone-xs-max-usado-IDHszIM.html
# Alcântara
# 29 de novembro de 2022
# ########################################################
# iPhone 11 128gb semi novo
# 11
# 449.0
# https://www.olx.pt/d/anuncio/iphone-11-128gb-semi-novo-IDHszEI.html
# Benfica
# 29 de novembro de 2022
# ########################################################
# iPhone 12 64/128/256 Gigas - NOVO/SELADO C/Garantia
# 12
# 689.0
# https://www.olx.pt/d/anuncio/iphone-12-64-128-256-gigas-novo-selado-c-garantia-IDH3IqA.html
# Parque das Nações
# 29 de novembro de 2022
# ########################################################
# iPhone 13 128/256/512 Gigas - NOVO/SELADO C/Garantia
# 13
# 809.0
# https://www.olx.pt/d/anuncio/iphone-13-128-256-512-gigas-novo-selado-c-garantia-IDH3IiI.html
# Montijo E Afonsoeiro
#  a 29 de novembro de 2022
# ########################################################
# iPhone 8 64GB Dourado A - Garantia 3 anos
# 8
# 179.0
# https://www.olx.pt/d/anuncio/iphone-8-64gb-dourado-a-garantia-3-anos-IDHheNZ.html
# Santa Clara
#  a 28 de novembro de 2022
# ########################################################
# Iphone 12 pro max 128GB
# 12
# 500.0
# https://www.olx.pt/d/anuncio/iphone-12-pro-max-128gb-IDHsEgc.html
# Corroios
# 29 de novembro de 2022
# ########################################################
# Iphone 13 pro max blue 256
# 13
# 1050.0
# https://www.olx.pt/d/anuncio/iphone-13-pro-max-blue-256-IDHsD9F.html
# Amora
# 29 de novembro de 2022
# ########################################################
# Iphone 11 Pro Max 64Gb cinza
# 11
# 500.0
# https://www.olx.pt/d/anuncio/iphone-11-pro-max-64gb-cinza-IDH8LxO.html
# Benfica
# 29 de novembro de 2022
# ########################################################
# iPhone 11 128gb para peças
# 11
# 200.0
# https://www.olx.pt/d/anuncio/iphone-11-128gb-para-peas-IDHpTUu.html
# Cascais E Estoril
# 29 de novembro de 2022
# ########################################################
# Iphone 11 Pro Max 64Gb
# 11
# 485.0
# https://www.olx.pt/d/anuncio/iphone-11-pro-max-64gb-IDHsCym.html
# Ericeira
# 29 de novembro de 2022
# ########################################################
# Iphone 11 Desbloqueado
# 11
# 420.0
# https://www.olx.pt/d/anuncio/iphone-11-desbloqueado-IDHszKZ.html
# Falagueira
# enda Nova
# ########################################################
# Iphone 7 Plus | 32Gb
# 7
# 150.0
# https://www.olx.pt/d/anuncio/iphone-7-plus-32gb-IDHjRGc.html
# Parque das Nações
# 29 de novembro de 2022
# ########################################################
# Iphone 14 pro max 1TB Deep Purple Selado.
# 14
# 2249.0
# https://www.olx.pt/d/anuncio/iphone-14-pro-max-1tb-deep-purple-selado-IDHsiGT.html
# Parque das Nações
# 29 de novembro de 2022
# ########################################################
# Iphone 14 Plus 128GB Purple Selado
# 14
# 950.0
# https://www.olx.pt/d/anuncio/iphone-14-plus-128gb-purple-selado-IDHsAi2.html
# Odivelas
# 29 de novembro de 2022
# ########################################################
# IPhone 11 pro 256 gb
# 11
# 450.0
# https://www.olx.pt/d/anuncio/iphone-11-pro-256-gb-IDHsBkl.html
# Águas Livres
# 29 de novembro de 2022
# ########################################################
# IPhone 12 Pro 512GB Azul A++ Garantia 3 Anos
# 12
# 869.0
# https://www.olx.pt/d/anuncio/iphone-12-pro-512gb-azul-a-garantia-3-anos-IDGiwTz.html
# Santa Clara
#  a 28 de novembro de 2022
# ########################################################
# iPhone 12 Pro Max 256GB Grafite A Garantia 3 Anos
# 12
# 879.0
# https://www.olx.pt/d/anuncio/iphone-12-pro-max-256gb-grafite-a-garantia-3-anos-IDGC2wO.html
# Santa Clara
#  a 28 de novembro de 2022
# ########################################################
# iPhone 13 128GB - NOVO/SELADO C/Garantia
# 13
# 809.0
# https://www.olx.pt/d/anuncio/iphone-13-128gb-novo-selado-c-garantia-IDHg2Zj.html
# Montijo E Afonsoeiro
#  a 28 de novembro de 2022
# ########################################################
# Iphone X 256gb grafite
# X
# 230.0
# https://www.olx.pt/d/anuncio/iphone-x-256gb-grafite-IDHmNjn.html
# São Domingos de Benfica
# 29 de novembro de 2022
# ########################################################
# IPhone 14 Plus 128gb e 256gb
# 14
# 990.0
# https://www.olx.pt/d/anuncio/iphone-14-plus-128gb-e-256gb-IDHiEmz.html
# Campo De Ourique
#  a 29 de novembro de 2022
# ########################################################
# Iphone 13 Pro 128GB
# 13
# 950.0
# https://www.olx.pt/d/anuncio/iphone-13-pro-128gb-IDH3Mux.html
# Vila Franca de Xira
# 29 de novembro de 2022
# ########################################################
# Iphone 11 Pro Max 256Gb
# 11
# 550.0
# https://www.olx.pt/d/anuncio/iphone-11-pro-max-256gb-IDHsBzS.html
# Quinta do Conde
# 29 de novembro de 2022
# ########################################################
# Iphone 8 Plus | 64Gb | Branco
# 8
# 250.0
# https://www.olx.pt/d/anuncio/iphone-8-plus-64gb-branco-IDHsFcb.html
# Ponte do Rol
# 29 de novembro de 2022
# ########################################################
# Iphone 14 Pro Max 128 Preto Sideral
# 14
# 1420.0
# https://www.olx.pt/d/anuncio/iphone-14-pro-max-128-preto-sideral-IDHsARP.html
# Benfica
# 29 de novembro de 2022
# ########################################################
# iphone xr apenas com ecra partido
# XR
# 250.0
# https://www.olx.pt/d/anuncio/iphone-xr-apenas-com-ecra-partido-IDHpJGi.html
# Águas Livres
# 29 de novembro de 2022
# ########################################################
# Iphone 7 128gb - Silver
# 7
# 155.0
# https://www.olx.pt/d/anuncio/iphone-7-128gb-silver-IDHszFZ.html
# Pontinha E Famões
# 29 de novembro de 2022
# ########################################################
# Iphone 11 de 64G
# 11
# 300.0
# https://www.olx.pt/d/anuncio/iphone-11-de-64g-IDHsyB7.html
# Odivelas
# 28 de novembro de 2022
# ########################################################
# iPhone Preto 64G Preço Único
# PR
# 250.0
# https://www.olx.pt/d/anuncio/iphone-preto-64g-preo-nico-IDHsBxI.html
# Massamá E Monte Abraão
# 29 de novembro de 2022
# ########################################################
# Black Friday! IPhone 14 PLUS 256gb novo e selado com garantia
# 14
# 1150.0
# https://www.olx.pt/d/anuncio/black-friday-iphone-14-plus-256gb-novo-e-selado-com-garantia-IDHiGqu.html
# Queluz E Belas
#  a 29 de novembro de 2022
# ########################################################
# Black Friday! IPhone 14 Plus 256gb novo e selado. Com garantia
# 14
# 1150.0
# https://www.olx.pt/d/anuncio/black-friday-iphone-14-plus-256gb-novo-e-selado-com-garantia-IDHpgxA.html
# Águas Livres
#  a 27 de novembro de 2022
# ########################################################
# Black Friday! IPhone 14 Pro 128gb Space Black. Selado e com garantia
# 14
# 1380.0
# https://www.olx.pt/d/anuncio/black-friday-iphone-14-pro-128gb-space-black-selado-e-com-garantia-IDHprM5.html
# Lumiar
#  a 29 de novembro de 2022
# ########################################################
# NOVO! IPhone 14 Plus 256Gb
# 14
# 999.0
# https://www.olx.pt/d/anuncio/novo-iphone-14-plus-256gb-IDHsz3j.html
# Benfica
# 28 de novembro de 2022
# ########################################################
# iPhone 11 64G Preço Único
# 11
# 250.0
# https://www.olx.pt/d/anuncio/iphone-11-64g-preo-nico-IDHsBw3.html
# Massamá E Monte Abraão
# 29 de novembro de 2022
# ########################################################
# Iphone SE 2020 .
# SE
# 180.0
# https://www.olx.pt/d/anuncio/iphone-se-2020-IDHpJ6F.html
# Alvalade
# 28 de novembro de 2022
# ########################################################
# Iphone 11 pro max 64g
# 11
# 250.0
# https://www.olx.pt/d/anuncio/iphone-11-pro-max-64g-IDHsBhN.html
# Queluz E Belas
# 29 de novembro de 2022
# ########################################################
# iPhone XS Max RoseGold
# XS
# 360.0
# https://www.olx.pt/d/anuncio/iphone-xs-max-rosegold-IDHmxHr.html
# Amora
# 29 de novembro de 2022
# ########################################################
# Iphone XS MAX 64gb
# XS
# 330.0
# https://www.olx.pt/d/anuncio/iphone-xs-max-64gb-IDG8a8D.html
# Oeiras E São Julião Da Barra, Paço De Arcos E Caxias
# 29 de novembro de 2022
# ########################################################
# iPhone 11 64gb Lilas
# 11
# 420.0
# https://www.olx.pt/d/anuncio/iphone-11-64gb-lilas-IDHsEkF.html
# Almada, Cova Da Piedade, Pragal E Cacilhas
# 29 de novembro de 2022
# ########################################################
# Iphone 12 mini usado
# 12
# 300.0
# https://www.olx.pt/d/anuncio/iphone-12-mini-usado-IDHsDSn.html
# Oeiras E São Julião Da Barra, Paço De Arcos E Caxias
# 29 de novembro de 2022
# ########################################################
# Iphone X, 256 gb
# X,
# 200.0
# https://www.olx.pt/d/anuncio/iphone-x-256-gb-IDHswKv.html
# Alcântara
# 28 de novembro de 2022
# ########################################################
# iPhone 13 Pro Max 128GB - Azul | Novo e Selado
# 13
# 1100.0
# https://www.olx.pt/d/anuncio/iphone-13-pro-max-128gb-azul-novo-e-selado-IDHpsc6.html
# Ramada E Caneças
# 29 de novembro de 2022

# %%
lista_zip = list(zip(descricao_lista,
modelo_lista,
preco_lista,
link_lista,
local_lista,
data_lista))

#Create Table
tabela = pd.DataFrame((lista_zip), columns=['descricao',
'modelo',
'preco',
'link',
'local',
'data'])

tabela.to_excel(r'C:\Users\joaoc\Desktop\Fivver\Fivver OLX\tabela_olx.xlsx', index = False)
# Out:
#                                             descricao modelo   preco  \
# 0   iPhone 11 Pro Max 256GB Cinzento A - Garantia ...     11   639.0
# 1   iPhone 13 Pro Max 128gb Sierra Blue - NOVO/SEL...     13  1199.0
# 2           iPhone 11 128GB Preto A - Garantia 3 Anos     11   439.0
# 3                              IPhone 11 128GB Silver     11   450.0
# 4   iPhone 12 128GB Azul + Capa MagSafe iPhone 12 ...     12   620.0
# 5                               IPhone 11 128GB Black     11   400.0
# 6                               IPhone 7 128GB Silver      7   150.0
# 7                             iPhone 12 Pro Max 128GB     12  1100.0
# 8                                 Iphone X 64GB preto      X   300.0
# 9                                   Iphone X de 64 GB      X   210.0
# 10                                  Iphone 12 Pro Max     12   760.0
# 11                                iPhone XS MAX usado     XS   280.0
# 12                          iPhone 11 128gb semi novo     11   449.0
# 13  iPhone 12 64/128/256 Gigas - NOVO/SELADO C/Gar...     12   689.0
# 14  iPhone 13 128/256/512 Gigas - NOVO/SELADO C/Ga...     13   809.0
# 15          iPhone 8 64GB Dourado A - Garantia 3 anos      8   179.0
# 16                            Iphone 12 pro max 128GB     12   500.0
# 39  Black Friday! IPhone 14 PLUS 256gb novo e sela...     14  1150.0
# 40  Black Friday! IPhone 14 Plus 256gb novo e sela...     14  1150.0
# 42                         NOVO! IPhone 14 Plus 256Gb     14   999.0
#
#                                                  link                  local  \
# 14  https://www.olx.pt/d/anuncio/iphone-13-128-256...  Montijo E Afonsoeiro
# 24  https://www.olx.pt/d/anuncio/iphone-14-plus-12...              Odivelas
# 28  https://www.olx.pt/d/anuncio/iphone-13-128gb-n...  Montijo E Afonsoeiro
# 30  https://www.olx.pt/d/anuncio/iphone-14-plus-12...      Campo De Ourique
# 39  https://www.olx.pt/d/anuncio/black-friday-ipho...        Queluz E Belas
# 40  https://www.olx.pt/d/anuncio/black-friday-ipho...          Águas Livres
# 42  https://www.olx.pt/d/anuncio/novo-iphone-14-pl...               Benfica
#
#                          data
# 14   a 29 de novembro de 2022
# 24     29 de novembro de 2022
# 28   a 28 de novembro de 2022
# 30   a 29 de novembro de 2022
# 39   a 29 de novembro de 2022
# 40   a 27 de novembro de 2022
# 42     28 de novembro de 2022

# %%
URL_mensagem_lista = []
anunciante_list = []
i=0
#ter a lista de URL
for row in tb.index :
    print(tb.iloc[i]['link'])
    URL_mensagem_lista.append(tb.iloc[i]['link'])  
    i=i+1
print(URL_mensagem_lista)

#Abrir navegador
navegador = webdriver.Chrome(ChromeDriverManager().install())
navegador.maximize_window()
#Loop obter lista anunciantes
for URL in URL_mensagem_lista:
    navegador.get(URL)
    time.sleep(1)
    try :
        navegador.find_element_by_xpath('//*[@id="onetrust-accept-btn-handler"]').click()
    except NoSuchElementException:
            pass
    time.sleep(1)
    try :
        anunciante = navegador.find_element_by_xpath('//*[@id="root"]/div[1]/div[3]/div[3]/div[2]/div[1]/div[2]/div/a/div/div[2]/h4').text
    except NoSuchElementException:
        anunciante = navegador.find_element_by_xpath('//*[@id="root"]/div[1]/div[3]/div[3]/div[1]/div[5]/div/div/div[1]/div/div[2]/h4').text
    except NoSuchElementException:
        anunciante = 'N/A'
        pass
    anunciante_list.append(anunciante)   

#navegador.quit()
tb['anunciante'] = anunciante_list
#print(tb)
# Out:
# https://www.olx.pt/d/anuncio/iphone-13-128-256-512-gigas-novo-selado-c-garantia-IDH3IiI.html
# https://www.olx.pt/d/anuncio/iphone-14-plus-128gb-purple-selado-IDHsAi2.html
# https://www.olx.pt/d/anuncio/iphone-13-128gb-novo-selado-c-garantia-IDHg2Zj.html
# https://www.olx.pt/d/anuncio/iphone-14-plus-128gb-e-256gb-IDHiEmz.html
# https://www.olx.pt/d/anuncio/black-friday-iphone-14-plus-256gb-novo-e-selado-com-garantia-IDHiGqu.html
# https://www.olx.pt/d/anuncio/black-friday-iphone-14-plus-256gb-novo-e-selado-com-garantia-IDHpgxA.html
# https://www.olx.pt/d/anuncio/novo-iphone-14-plus-256gb-IDHsz3j.html
# ['https://www.olx.pt/d/anuncio/iphone-13-128-256-512-gigas-novo-selado-c-garantia-IDH3IiI.html', 'https://www.olx.pt/d/anuncio/iphone-14-plus-128gb-purple-selado-IDHsAi2.html', 'https://www.olx.pt/d/anuncio/iphone-13-128gb-novo-selado-c-garantia-IDHg2Zj.html', 'https://www.olx.pt/d/anuncio/iphone-14-plus-128gb-e-256gb-IDHiEmz.html', 'https://www.olx.pt/d/anuncio/black-friday-iphone-14-plus-256gb-novo-e-selado-com-garantia-IDHiGqu.html', 'https://www.olx.pt/d/anuncio/black-friday-iphone-14-plus-256gb-novo-e-selado-com-garantia-IDHpgxA.html', 'https://www.olx.pt/d/anuncio/novo-iphone-14-plus-256gb-IDHsz3j.html']
#                                             descricao modelo   preco  \
# 14  iPhone 13 128/256/512 Gigas - NOVO/SELADO C/Ga...     13   809.0
# 24                 Iphone 14 Plus 128GB Purple Selado     14   950.0
# 28           iPhone 13 128GB - NOVO/SELADO C/Garantia     13   809.0
# 30                       IPhone 14 Plus 128gb e 256gb     14   990.0
# 39  Black Friday! IPhone 14 PLUS 256gb novo e sela...     14  1150.0
# 40  Black Friday! IPhone 14 Plus 256gb novo e sela...     14  1150.0
# 42                         NOVO! IPhone 14 Plus 256Gb     14   999.0
#
#                                                  link                  local  \
# 14  https://www.olx.pt/d/anuncio/iphone-13-128-256...  Montijo E Afonsoeiro
# 24  https://www.olx.pt/d/anuncio/iphone-14-plus-12...              Odivelas
# 28  https://www.olx.pt/d/anuncio/iphone-13-128gb-n...  Montijo E Afonsoeiro
# 30  https://www.olx.pt/d/anuncio/iphone-14-plus-12...      Campo De Ourique
# 39  https://www.olx.pt/d/anuncio/black-friday-ipho...        Queluz E Belas
# 40  https://www.olx.pt/d/anuncio/black-friday-ipho...          Águas Livres
# 42  https://www.olx.pt/d/anuncio/novo-iphone-14-pl...               Benfica
#
#                          data      anunciante
# 14   a 29 de novembro de 2022  Netmore Outlet
# 24     29 de novembro de 2022  Gabriel Bastos
# 28   a 28 de novembro de 2022  Netmore Outlet
# 30   a 29 de novembro de 2022   Ricardo Seara
# 39   a 29 de novembro de 2022   Ricardo Seara
# 40   a 27 de novembro de 2022   Ricardo Seara
# 42     28 de novembro de 2022          FPinho

# %%
#excluir nome anunciantes
tb_nomes = tb[tb.anunciante.isin(nomes_concorrentes) == False]

#print(tb_nomes)

#Ler o documento de anuncios enviados para nao enviar de novo
enviados_excluir = pd.read_excel('enviados_mensagem.xlsx')
link_enviados = enviados_excluir['link'].values.tolist()
#print (link_enviados)

#Excluir os já enviados da lista a enviar
tb_enviar = tb_nomes[tb_nomes.link.isin(link_enviados) == False]
print ('Filtragem de anunciantes feita')
#print(tb_enviar)
# Out:
#                                             descricao modelo   preco  \
# 14  iPhone 13 128/256/512 Gigas - NOVO/SELADO C/Ga...     13   809.0
# 24                 Iphone 14 Plus 128GB Purple Selado     14   950.0
# 28           iPhone 13 128GB - NOVO/SELADO C/Garantia     13   809.0
# 30                       IPhone 14 Plus 128gb e 256gb     14   990.0
# 39  Black Friday! IPhone 14 PLUS 256gb novo e sela...     14  1150.0
# 40  Black Friday! IPhone 14 Plus 256gb novo e sela...     14  1150.0
# 42                         NOVO! IPhone 14 Plus 256Gb     14   999.0
#
#                                                  link                  local  \
# 14  https://www.olx.pt/d/anuncio/iphone-13-128-256...  Montijo E Afonsoeiro
# 24  https://www.olx.pt/d/anuncio/iphone-14-plus-12...              Odivelas
# 28  https://www.olx.pt/d/anuncio/iphone-13-128gb-n...  Montijo E Afonsoeiro
# 30  https://www.olx.pt/d/anuncio/iphone-14-plus-12...      Campo De Ourique
# 39  https://www.olx.pt/d/anuncio/black-friday-ipho...        Queluz E Belas
# 40  https://www.olx.pt/d/anuncio/black-friday-ipho...          Águas Livres
# 42  https://www.olx.pt/d/anuncio/novo-iphone-14-pl...               Benfica
#
#                          data      anunciante
# 14   a 29 de novembro de 2022  Netmore Outlet
# 24     29 de novembro de 2022  Gabriel Bastos
# 28   a 28 de novembro de 2022  Netmore Outlet
# 30   a 29 de novembro de 2022   Ricardo Seara
# 39   a 29 de novembro de 2022   Ricardo Seara
# 40   a 27 de novembro de 2022   Ricardo Seara
# 42     28 de novembro de 2022          FPinho
# ['teste', 'https://www.olx.pt/d/anuncio/iphone-13-128gb-novo-IDHkLQc.html', 'https://www.olx.pt/d/anuncio/iphone-14-128gb-novo-na-caixa-selado-e-com-garantia-IDHpgvn.html', 'https://www.olx.pt/d/anuncio/iphone-13-rosa-128gb-IDHss4n.html', 'https://www.olx.pt/d/anuncio/iphone-13-blue-128-gb-com-garantia-IDHrXgx.html', 'https://www.olx.pt/d/anuncio/iphone-13-128-gbs-novo-IDHspmr.html']
# Filtragem completa
#                                             descricao modelo   preco  \
# 14  iPhone 13 128/256/512 Gigas - NOVO/SELADO C/Ga...     13   809.0
# 24                 Iphone 14 Plus 128GB Purple Selado     14   950.0
# 28           iPhone 13 128GB - NOVO/SELADO C/Garantia     13   809.0
# 30                       IPhone 14 Plus 128gb e 256gb     14   990.0
# 39  Black Friday! IPhone 14 PLUS 256gb novo e sela...     14  1150.0
# 40  Black Friday! IPhone 14 Plus 256gb novo e sela...     14  1150.0
# 42                         NOVO! IPhone 14 Plus 256Gb     14   999.0
#
#                                                  link                  local  \
# 14  https://www.olx.pt/d/anuncio/iphone-13-128-256...  Montijo E Afonsoeiro
# 24  https://www.olx.pt/d/anuncio/iphone-14-plus-12...              Odivelas
# 28  https://www.olx.pt/d/anuncio/iphone-13-128gb-n...  Montijo E Afonsoeiro
# 30  https://www.olx.pt/d/anuncio/iphone-14-plus-12...      Campo De Ourique
# 39  https://www.olx.pt/d/anuncio/black-friday-ipho...        Queluz E Belas
# 40  https://www.olx.pt/d/anuncio/black-friday-ipho...          Águas Livres
# 42  https://www.olx.pt/d/anuncio/novo-iphone-14-pl...               Benfica
#
#                          data      anunciante
# 14   a 29 de novembro de 2022  Netmore Outlet
# 24     29 de novembro de 2022  Gabriel Bastos
# 28   a 28 de novembro de 2022  Netmore Outlet
# 30   a 29 de novembro de 2022   Ricardo Seara
# 39   a 29 de novembro de 2022   Ricardo Seara
# 40   a 27 de novembro de 2022   Ricardo Seara
# 42     28 de novembro de 2022          FPinho

# %%
#ter a lista de URL para enviar
URL_mensagem_lista_final = []
j = 0
for row in tb_enviar.index :
    #print(tb_enviar.iloc[j]['link'])
    URL_mensagem_lista_final.append(tb_enviar.iloc[j]['link']) 
    j=j+1

#print(URL_mensagem_lista_final)
# Out:
# https://www.olx.pt/d/anuncio/iphone-13-128-256-512-gigas-novo-selado-c-garantia-IDH3IiI.html
# https://www.olx.pt/d/anuncio/iphone-14-plus-128gb-purple-selado-IDHsAi2.html
# https://www.olx.pt/d/anuncio/iphone-13-128gb-novo-selado-c-garantia-IDHg2Zj.html
# https://www.olx.pt/d/anuncio/iphone-14-plus-128gb-e-256gb-IDHiEmz.html
# https://www.olx.pt/d/anuncio/black-friday-iphone-14-plus-256gb-novo-e-selado-com-garantia-IDHiGqu.html
# https://www.olx.pt/d/anuncio/black-friday-iphone-14-plus-256gb-novo-e-selado-com-garantia-IDHpgxA.html
# https://www.olx.pt/d/anuncio/novo-iphone-14-plus-256gb-IDHsz3j.html
# ['https://www.olx.pt/d/anuncio/iphone-13-128-256-512-gigas-novo-selado-c-garantia-IDH3IiI.html', 'https://www.olx.pt/d/anuncio/iphone-14-plus-128gb-purple-selado-IDHsAi2.html', 'https://www.olx.pt/d/anuncio/iphone-13-128gb-novo-selado-c-garantia-IDHg2Zj.html', 'https://www.olx.pt/d/anuncio/iphone-14-plus-128gb-e-256gb-IDHiEmz.html', 'https://www.olx.pt/d/anuncio/black-friday-iphone-14-plus-256gb-novo-e-selado-com-garantia-IDHiGqu.html', 'https://www.olx.pt/d/anuncio/black-friday-iphone-14-plus-256gb-novo-e-selado-com-garantia-IDHpgxA.html', 'https://www.olx.pt/d/anuncio/novo-iphone-14-plus-256gb-IDHsz3j.html']

# %%
#enviar mensagem a quem resta
#abrir pagina
navegador = webdriver.Chrome(ChromeDriverManager().install())
navegador.maximize_window()
k=1

#para cada anuncio da tabela a enviar, enviar a mensagem
for URL_enviar in URL_mensagem_lista_final:
    navegador.get(URL_enviar)
    #aceitar cookies
    time.sleep(2)
    try :
        navegador.find_element_by_xpath('//*[@id="onetrust-accept-btn-handler"]').click()
    except NoSuchElementException:
        pass
    #carregar botao enviar mensagem para fazer login
    time.sleep( randint ( 2, 4 ) )
    navegador.find_element_by_xpath('//*[@id="root"]/div[1]/div[3]/div[3]/div[1]/div[4]/section/div/div/form/div[1]').click()
    
    time.sleep( randint ( 1, 2 ) )
    #fazer login
    try :
        navegador.find_element_by_xpath('//*[@id="__next"]/div/div/div/div/main/div/div[2]/div/form/div[1]/div/div/input').click()
        navegador.find_element_by_xpath('//*[@id="__next"]/div/div/div/div/main/div/div[2]/div/form/div[1]/div/div/input').send_keys(username)
        time.sleep( randint ( 1, 3 ) )
        navegador.find_element_by_xpath('//*[@id="__next"]/div/div/div/div/main/div/div[2]/div/form/div[2]/div/div/div/input').click()
        navegador.find_element_by_xpath('//*[@id="__next"]/div/div/div/div/main/div/div[2]/div/form/div[2]/div/div/div/input').send_keys(password)
        time.sleep( randint ( 1, 3 ) )
        navegador.find_element_by_xpath('//*[@id="__next"]/div/div/div/div/main/div/div[2]/div/form/div[2]/div/div/div/input').send_keys(Keys.ENTER)
    except NoSuchElementException:
        pass
  
    #carregar botao enviar mensagem 
    time.sleep (3)
    time.sleep( randint ( 1, 3 ) )   
    navegador.execute_script("window.scrollTo(0, 1080)") 
    time.sleep( randint ( 1, 3 ) )
    navegador.find_element_by_xpath('//*[@id="root"]/div[1]/div[3]/div[3]/div[1]/div[4]/section/div/div/form/div/div[1]/textarea').send_keys(mensagem1)
    time.sleep( randint ( 1, 3 ) )
    navegador.find_element_by_xpath('//*[@id="root"]/div[1]/div[3]/div[3]/div[1]/div[4]/section/div/div/form/div/div[1]/textarea').send_keys(mensagem2)
    print('mensagem '+str(k)+' enviada')
    k=k+1

print ('Mensagens enviadas')
# Out:
# mensagem 1 enviada
# mensagem 2 enviada
# mensagem 3 enviada
# mensagem 4 enviada
# mensagem 5 enviada
# mensagem 6 enviada
# mensagem 7 enviada
# Mensagens enviadas

# %%
#Adicionar anuncios com mensagem enviada na lista enviados 
from openpyxl import Workbook
from openpyxl import load_workbook
rows = tb_enviar.values.tolist()
workbook = load_workbook(filename='enviados_mensagem.xlsx')
sheet = workbook['Sheet1']
for row in rows:
    sheet.append(row)
workbook.save(filename='enviados_mensagem.xlsx')
print ('Enviados adicionados a lista')
print ('Programa rodado com sucesso')
# Out:
# Enviados adicionados a lista
